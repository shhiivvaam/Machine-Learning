# %%
from sklearn.cluster import KMeans
import pandas as pd
df = pd.read_csv("income.csv")
df
# Out:
#          name  age  income
# 0        Aman   27   70000
# 1        Ajay   29   90000
# 2      Madhav   29   61000
# 3       Aryan   28   60000
# 4   Prathmesh   42  150000
# 5       Rahul   39  155000
# 6         Tom   41  160000
# 7       Mohan   38  162000
# 8         Sam   36  156000
# 9      Naresh   35  130000
# 10     Ekansh   37  137000
# 11   Gitanshu   26   45000
# 12     Sudhir   27   48000
# 13     Sujeet   28   51000
# 14      Raman   29   49500
# 15      Rajat   32   53000
# 16     Sparsh   40   65000
# 17    Mitansh   41   63000
# 18    Natansh   43   64000
# 19      Arpit   39   80000
# 20     Atharv   41   82000
# 21   Priyanka   39   58000

# %%
import matplotlib.pyplot as plt
plt.scatter(df['age'],df['income'])
plt.xlabel('age')
plt.ylabel('income')
plt.show()

# %%
model = KMeans(n_clusters=3)
y_pred = model.fit_predict(df[['age','income']])
print(y_pred)
# Out:
# [1 1 2 2 0 0 0 0 0 0 0 2 2 2 2 2 2 2 2 1 1 2]

# %%
df['cluster'] = y_pred
df
# Out:
#          name  age  income  cluster
# 0        Aman   27   70000        1
# 1        Ajay   29   90000        1
# 2      Madhav   29   61000        2
# 3       Aryan   28   60000        2
# 4   Prathmesh   42  150000        0
# 5       Rahul   39  155000        0
# 6         Tom   41  160000        0
# 7       Mohan   38  162000        0
# 8         Sam   36  156000        0
# 9      Naresh   35  130000        0
# 10     Ekansh   37  137000        0
# 11   Gitanshu   26   45000        2
# 12     Sudhir   27   48000        2
# 13     Sujeet   28   51000        2
# 14      Raman   29   49500        2
# 15      Rajat   32   53000        2
# 16     Sparsh   40   65000        2
# 17    Mitansh   41   63000        2
# 18    Natansh   43   64000        2
# 19      Arpit   39   80000        1
# 20     Atharv   41   82000        1
# 21   Priyanka   39   58000        2

# %%
print(model.cluster_centers_)
# Out:
# [[3.82857143e+01 1.50000000e+05]
#  [3.40000000e+01 8.05000000e+04]
#  [3.29090909e+01 5.61363636e+04]]

# %%
df1 = df[df['cluster']==0]
df2 = df[df['cluster']==1]
df3 = df[df['cluster']==2]

# %%
plt.scatter(df1['age'],df1['income'],color = 'red')
plt.scatter(df2['age'],df2['income'],color = 'green')
plt.scatter(df3['age'],df3['income'],color = 'blue')

plt.xlabel('age')
plt.ylabel('income')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.preprocessing import MinMaxScaler
dfnew = df
scaler = MinMaxScaler()
scaler.fit(dfnew[['income']])
dfnew['income'] = scaler.transform(dfnew[['age']])

scaler.fit(df[['age']])
dfnew['age'] = scaler.transform(dfnew[['age']])
dfnew
# Out:
# c:\Users\Shivam Kumar\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - age
# Feature names seen at fit time, yet now missing:
# - income
#
#   warnings.warn(message, FutureWarning)
#          name       age        income  cluster
# 0        Aman  0.058824  11084.885813        1
# 1        Ajay  0.176471  11894.574394        1
# 2      Madhav  0.176471  11894.574394        1
# 3       Aryan  0.117647  11489.730104        1
# 4   Prathmesh  0.941176  17157.550173        2
# 5       Rahul  0.764706  15943.017301        2
# 6         Tom  0.882353  16752.705882        2
# 7       Mohan  0.705882  15538.173010        2
# 8         Sam  0.588235  14728.484429        0
# 9      Naresh  0.529412  14323.640138        0
# 10     Ekansh  0.647059  15133.328720        0
# 11   Gitanshu  0.000000  10680.041522        1
# 12     Sudhir  0.058824  11084.885813        1
# 13     Sujeet  0.117647  11489.730104        1
# 14      Raman  0.176471  11894.574394        1
# 15      Rajat  0.352941  13109.107266        0
# 16     Sparsh  0.823529  16347.861592        2
# 17    Mitansh  0.882353  16752.705882        2
# 18    Natansh  1.000000  17562.394464        2
# 19      Arpit  0.764706  15943.017301        2
# 20     Atharv  0.882353  16752.705882        2
# 21   Priyanka  0.764706  15943.017301        2

# %%
df1 = df[df['cluster']==0]
df2 = df[df['cluster']==1]
df3 = df[df['cluster']==2]

# %%
model1 = KMeans(n_clusters=3)
y_pred1 = model1.fit_predict(dfnew[['age','income']])
print(y_pred)
# Out:
# [1 1 2 2 0 0 0 0 0 0 0 2 2 2 2 2 2 2 2 1 1 2]

# %%
dfnew['cluster'] = y_pred1
print(model1.cluster_centers_)
# Out:
# [[ 0.52941176 -1.55172398]
#  [ 0.11029412 -1.55178488]
#  [ 0.84117647 -1.55167868]]

# %%
df11 = dfnew[df['cluster']==0]
df22 = dfnew[df['cluster']==1]
df33 = dfnew[df['cluster']==2]

plt.scatter(df11['age'],df11['income'],color = 'red')
plt.scatter(df22['age'],df22['income'],color = 'green')
plt.scatter(df33['age'],df33['income'],color = 'blue')

plt.scatter(model1.cluster_centers_[:,0],model1.cluster_centers_[:,1],marker = '*', color = 'magenta')

plt.xlabel('age')
plt.ylabel('income')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <!-- ELBOW **METHOD** -->

# %%
sse = []
for i in range(1,11):
    model2 = KMeans(n_clusters = i)
    model2.fit(df[['age','income']])
    sse.append(model2.inertia_)

# %%
sse
# Out:
# [119854797.89464135,
#  14876977.361745447,
#  7371353.168625856,
#  4273663.899320053,
#  2634674.8679413204,
#  1486016.7217833905,
#  961540.2317421898,
#  715691.8770353793,
#  532671.4351980875,
#  396089.0159165256]

# %%
plt.xlabel('K')
plt.ylabel('Sum of Squared Error')
plt.plot(range(1,11),sse)
plt.show()
